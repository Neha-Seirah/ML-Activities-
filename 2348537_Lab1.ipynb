# %% [markdown]
# <a href="https://colab.research.google.com/github/Neha-Seirah/ML-Activities-/blob/main/2348537_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
data=pd.read_csv('/content/Churn_Modelling.csv')
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
data.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
data=data.drop(columns='CustomerId', axis=1)
data=data.drop(columns='Surname', axis=1)
data=data.drop(columns='RowNumber', axis=1)

# %%
sns.boxplot(data['CreditScore'])
# Out:
# <Axes: >

# %%
data['CreditScore'].describe()
# Out:
# count    10000.000000
# mean       650.528800
# std         96.653299
# min        350.000000
# 25%        584.000000
# 50%        652.000000
# 75%        718.000000
# max        850.000000
# Name: CreditScore, dtype: float64

# %%
b = np.where(data['CreditScore']>718) or (data['CreditScore']<584)
a = np.array(b[0])
len(a)
# Out:
# 2463

# %%
def drop_outlier(data,col_name):
  print(data.shape)
  z = np.abs(stats.zscore(col_name))
  data.drop(data.index[np.where(abs(z)>2.5)],inplace=True)
  print("New data shape post deletion: "+str(data.shape))

# %%
drop_outlier(data,data['CreditScore'])
# Out:
# (10000, 11)
# New data shape post deletion: (9974, 11)

# %%
drop_outlier(data,data['EstimatedSalary'])
# Out:
# (9974, 11)
# New data shape post deletion: (9974, 11)

# %%
drop_outlier(data,data['Balance'])
# Out:
# (9974, 11)
# New data shape post deletion: (9972, 11)

# %%
from sklearn.preprocessing import LabelEncoder
for col in ['Geography','Gender']:
  le=LabelEncoder()
  data[col]=le.fit_transform(data[col])

# %%
data.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       0   42       2       0.00              1
# 1          608          2       0   41       1   83807.86              1
# 2          502          0       0   42       8  159660.80              3
# 3          699          0       0   39       1       0.00              2
# 4          850          2       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
data.corr()
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
data.corr()
# Out:
#                  CreditScore  Geography    Gender       Age    Tenure  \
# CreditScore         1.000000   0.009857 -0.003765  0.000265 -0.000713
# Geography           0.009857   1.000000  0.004435  0.023278  0.004658
# Gender             -0.003765   0.004435  1.000000 -0.026409  0.015068
# Age                 0.000265   0.023278 -0.026409  1.000000 -0.010429
# Tenure             -0.000713   0.004658  0.015068 -0.010429  1.000000
# Balance             0.007724   0.068342  0.012971  0.027729 -0.011439
# NumOfProducts       0.010541   0.002986 -0.021650 -0.028795  0.013290
# HasCrCard          -0.003935  -0.009084  0.005586 -0.010844  0.022521
# IsActiveMember      0.022930   0.006407  0.022124  0.086652 -0.027639
# EstimatedSalary     0.002176  -0.001326 -0.008008 -0.008982  0.007710
# Exited             -0.013888   0.034561 -0.106246  0.284040 -0.013004
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# CreditScore      0.007724       0.010541  -0.003935        0.022930
# Geography        0.068342       0.002986  -0.009084        0.006407
# Gender           0.012971      -0.021650   0.005586        0.022124
# Age              0.027729      -0.028795  -0.010844        0.086652
# Tenure          -0.011439       0.013290   0.022521       -0.027639
# Balance          1.000000      -0.306873  -0.014632       -0.010320
# NumOfProducts   -0.306873       1.000000   0.003623        0.009941
# HasCrCard       -0.014632       0.003623   1.000000       -0.012031
# IsActiveMember  -0.010320       0.009941  -0.012031        1.000000
# EstimatedSalary  0.012461       0.015015  -0.009929       -0.010520
# Exited           0.117456      -0.046821  -0.007954       -0.155408
#
#                  EstimatedSalary    Exited
# CreditScore             0.002176 -0.013888
# Geography              -0.001326  0.034561
# Gender                 -0.008008 -0.106246
# Age                    -0.008982  0.284040
# Tenure                  0.007710 -0.013004
# Balance                 0.012461  0.117456
# NumOfProducts           0.015015 -0.046821
# HasCrCard              -0.009929 -0.007954
# IsActiveMember         -0.010520 -0.155408
# EstimatedSalary         1.000000  0.009697
# Exited                  0.009697  1.000000

# %%
from sklearn.feature_selection import chi2
X=data.drop(columns=['Exited'])
Y=data['Exited']

# %%
chi_scores=chi2(X,Y)
chi_values=pd.Series(chi_scores[0],index=X.columns)
chi_values.sort_values(ascending=False,inplace=True)
chi_values.plot.bar()
# Out:
# <Axes: >

# %%
p_values=pd.Series(chi_scores[1],index=X.columns)
p_values.sort_values(ascending=False,inplace=True)
p_values.plot.bar()
# Out:
# <Axes: >

# %%
required=['CreditScore','Age','Tenure','Balance','EstimatedSalary']
sc = StandardScaler()
data[required] = sc.fit_transform(data[required])

# %%
data.head()
# Out:
#    CreditScore  Geography  Gender       Age    Tenure   Balance  \
# 0    -0.336724          0       0  0.295369 -1.042623 -1.225585
# 1    -0.451589          2       0  0.199940 -1.388476  0.118339
# 2    -1.558465          0       0  0.295369  1.032496  1.334699
# 3     0.498654          0       0  0.009082 -1.388476 -1.225585
# 4     2.075431          2       0  0.390798 -1.042623  0.787078
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0              1          1               1         0.023120       1
# 1              1          0               1         0.217715       0
# 2              3          1               0         0.241861       1
# 3              2          0               0        -0.107649       0
# 4              1          1               1        -0.363938       0

# %%
cat = data[['HasCrCard', 'IsActiveMember', 'Geography', 'NumOfProducts', 'Gender','Tenure','CreditScore','Age','Balance','EstimatedSalary']]
X=cat
pca = PCA(n_components=5)
np.ascontiguousarray(pca.fit_transform(X))
# Out:
# array([[-0.69024783,  0.98259071,  0.04667715, -0.85832907,  0.74173878],
#        [ 0.75025646,  0.61331985,  0.2718347 , -1.16772863,  0.19571769],
#        [ 0.4565472 , -0.54343115,  1.82441251,  0.68517871, -0.12462176],
#        ...,
#        [-1.24006079,  0.50714996, -0.73920286,  0.89529672, -0.24725167],
#        [ 0.28962795,  0.29949043, -1.34830215, -0.29132574,  0.23767327],
#        [ 0.42152917,  0.07556617, -1.52547406, -0.06514442, -1.65766139]])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.15962013, 0.15074267, 0.14855504, 0.14737544, 0.14555173])

# %%
pca = PCA(n_components=4)
np.ascontiguousarray(pca.fit_transform(X))
pca.explained_variance_ratio_
# Out:
# array([0.15962013, 0.15074267, 0.14855504, 0.14737544])

# %%
pca = PCA(n_components=3)
np.ascontiguousarray(pca.fit_transform(X))
pca.explained_variance_ratio_
# Out:
# array([0.15962013, 0.15074267, 0.14855504])
